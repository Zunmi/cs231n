# %%
import os
import sys

ASSIGNMENT_DIR = "/data/users/huanghao/a3/assignment3"
assert os.path.isdir(ASSIGNMENT_DIR), f"[!] Assignment directory not found: {ASSIGNMENT_DIR}"

os.chdir(ASSIGNMENT_DIR)
if ASSIGNMENT_DIR not in sys.path:
    sys.path.append(ASSIGNMENT_DIR)

print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /data/users/huanghao/a3/assignment3

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# <font color="red">**Note:** Remember to execute ALL notebooks' cells before this step. We won't be regrading missing cell outputs.</font>
#
# Run this notebook once you have completed all the other notebooks.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a3_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `a3_inline_submission.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a3_code_submission.zip and a3_inline_submission.pdf to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on successfully completing the assignment!

# %%
# %cd /data/users/huanghao/a3/assignment3
# !bash collectSubmission.sh
# Out:
# /data/users/huanghao/a3/assignment3
# ### Zipping file ###
# ### Creating PDFs ###
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# Created PDF Transformer_Captioning.ipynb.
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# Created PDF Self_Supervised_Learning.ipynb.
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# Created PDF DDPM.ipynb.
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# /data/users/huanghao/miniconda3/envs/cs224n-a3/lib/python3.8/site-packages/nbconvert/utils/pandoc.py:52: RuntimeWarning: You are using an unsupported version of pandoc (3.9.0.2).
# Your version must be at least (1.12.1) but less than (2.0.0).
# Refer to http://pandoc.org/installing.html.
# Continuing with doubts...
#   check_pandoc_version()
# Created PDF CLIP_DINO.ipynb.
# ### Done! Please submit a3_code_submission.zip and a3_inline_submission.pdf to Gradescope. ###
